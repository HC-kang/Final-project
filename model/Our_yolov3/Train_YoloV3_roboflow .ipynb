# %% [markdown]
# **Connect google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Sat Aug  7 00:34:36 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  수학					 'Linear_Regression_(TF_2_0).ipynb'
#  이미지임시				 'My Drive'
# '제목없는 폴더'				  new_garbage
# '유학원 상담카드 실습문제-0329.gsheet'	  nlp
# '제목 없는 스프레드시트 (1).gsheet'	  NLP_자연어
# '(실습)[2-1-1]생활데이터처리하기.ipynb'   NLP.txt
# '(실습)[2-1-2]생활데이터처리하기.ipynb'   passby_data.CSV
#  archive				  pima-indians-diabetes.csv
#  chatbot				  Predict_Future_Sales.ipynb
# 'Colab Notebooks'			  requirements.txt
#  dacon					  sonar.csv
#  data_flow.gsheet			  spam.csv
#  dataset				  test1.ipynb
# '제목없는 지도.gmap'			  test3.gsheet
# '할 일 목록.gsheet'			  test_for_pic
# '제목 없는 스프레드시트.gsheet'		  ThoraricSurgery.csv
#  iris.csv				  tmdb_5000_movies.csv
#  kaggle					  연습_yolo.ipynb
# 'Learning Progress.xlsx'		  yolov3

# %% [markdown]
# **1) Clone the Darknet**

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15298, done.
# remote: Total 15298 (delta 0), reused 0 (delta 0), pack-reused 15298
# Receiving objects: 100% (15298/15298), 13.68 MiB | 2.88 MiB/s, done.
# Resolving deltas: 100% (10389/10389), done.

# %% [markdown]
# # 새 섹션

# %% [markdown]
# **2) Compile Darknet using Nvidia GPU**

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %% [markdown]
# **3) Configure Darknet network for training YOLO V3**

# %%
pwd
# Out:
# '/content/darknet'

# %%
#!cp cfg/yolov3.cfg cfg/yolov3_training.cfg
# !cp /mydrive/yolov3/data/yolov3_testing.cfg cfg/yolov3_training.cfg

# %%
# !echo -e '' > data/obj.names
# !echo -e '' > data/obj.data
# !cp /mydrive/yolov3/data/obj.names data/obj.names
# !cp /mydrive/yolov3/data/obj.data data/obj.data
# !mkdir data/obj

# %%
# Download weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-08-07 00:36:02--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  20.4MB/s    in 8.6s
#
# 2021-08-07 00:36:11 (17.9 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# **4) Extract Images**
#
# The images need to be inside a zip archive called "images.zip" and they need to be inside the folder "yolov3" on Google Drive

# %%
# !unzip /mydrive/yolov3/images.zip -d data/obj
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: data/obj/plastic464_jpg.rf.6efb657f064993e39dedd8bb1ce6832f.jpg
#   inflating: data/obj/plastic464_jpg.rf.6efb657f064993e39dedd8bb1ce6832f.txt
#   inflating: data/obj/plastic464_jpg.rf.8b594ecd356afe8659c2349eac3800af.jpg
#   inflating: data/obj/plastic464_jpg.rf.8b594ecd356afe8659c2349eac3800af.txt
#   inflating: data/obj/plastic464_jpg.rf.ee74a6180e7b96353578e2f7ab7ae76f.jpg
#   inflating: data/obj/plastic464_jpg.rf.ee74a6180e7b96353578e2f7ab7ae76f.txt
#   inflating: data/obj/plastic465_jpg.rf.3f141315e5abba0a24ed90a1835a8140.jpg
#   inflating: data/obj/plastic465_jpg.rf.3f141315e5abba0a24ed90a1835a8140.txt
#   inflating: data/obj/plastic465_jpg.rf.9f59203eceacae47ad80d5ebb314e270.jpg
#   inflating: data/obj/plastic465_jpg.rf.9f59203eceacae47ad80d5ebb314e270.txt
#   inflating: data/obj/plastic465_jpg.rf.ba120a95604c4659f72fe23bff992086.jpg
#   inflating: data/obj/plastic465_jpg.rf.ba120a95604c4659f72fe23bff992086.txt
# ...

# %%
import glob
images_list = glob.glob("data/obj/*.jpg")
#images_list = glob.glob("data/obj/*.png")
print(images_list)
# Out:
# ['data/obj/vinyl--439-_jpg.rf.a1c91525651cad3883e733fa325baec8.jpg', 'data/obj/glass493_jpg.rf.20a9c80efdde4cb1e453cecb7c1885e1.jpg', 'data/obj/plastic229_jpg.rf.1a29780df18ee599759307af13a70f93.jpg', 'data/obj/paper11_jpg.rf.76fc719b28d11392178986627bae70ec.jpg', 'data/obj/vinyl--215-_jpg.rf.19f8d0b17ef7aebfca9a9e84b5bd8b42.jpg', 'data/obj/glass222_jpg.rf.893a44d34942f3e17e323ef64c3275c2.jpg', 'data/obj/plastic154_jpg.rf.f6762f201c72a7a92e9dce2d8a4f1f49.jpg', 'data/obj/vinyl--414-_jpg.rf.ddee542d75f622056cc84bbdb5e505b9.jpg', 'data/obj/glass313_jpg.rf.d6007014f73784a4dab6cb324cbd7985.jpg', 'data/obj/plastic92_jpg.rf.e1774a981817c6632e407f25b15ffd75.jpg', 'data/obj/glass112_jpg.rf.f437ce882b879635accd22a5dc4d8bc2.jpg', 'data/obj/paper127_jpg.rf.8127bf989618a5a032747e7ecc153bd2.jpg', 'data/obj/glass54_jpg.rf.a2e62f2b4f89198b87018a0fa8441982.jpg', 'data/obj/vinyl--100-_jpg.rf.2bc755a077905fd38ccc16ac0c4c142a.jpg', 'data/obj/glass418_jpg.rf.75f747ac20d7e82a685c309e7d379801.jpg', 'data/o
# ...

# %%
# Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %% [markdown]
# **6) Start the training**

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show | tee backup/train.log
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 400490, rewritten_bbox = 0.051187 %
# Loaded: 0.000109 seconds
#
#  45535: 0.065961, 0.181371 avg loss, 0.000010 rate, 0.385548 seconds, 364280 images, 0.045670 hours left
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.885647), count: 8, class_loss = 0.550053, iou_loss = 0.125304, total_loss = 0.675357
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# ...

# %%
# !./darknet detector test data/obj.data /mydrive/yolov3/data/yolov3_testing.cfg /mydrive/yolov3/yolov3_training_last.weights -thresh 0.25
